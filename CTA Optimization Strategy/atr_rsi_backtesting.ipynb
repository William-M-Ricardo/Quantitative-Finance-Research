# %%
from datetime import datetime

from vnpy_ctastrategy.backtesting import BacktestingEngine, OptimizationSetting

from atr_rsi_demo import AtrRsiDemo

# %%
engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="IF99.CFFEX",
    interval="1m",
    start=datetime(2020, 1, 1),
    end=datetime(2023, 12, 31),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)

setting = {}
engine.add_strategy(AtrRsiDemo, setting)

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2025-07-25 09:17:17.364508	开始加载历史数据
# 2025-07-25 09:17:17.364508	加载进度：# [0%]
# 2025-07-25 09:17:18.440467	加载进度：## [10%]
# 2025-07-25 09:17:19.543327	加载进度：### [20%]
# 2025-07-25 09:17:20.774186	加载进度：#### [30%]
# 2025-07-25 09:17:21.935739	加载进度：##### [40%]
# 2025-07-25 09:17:23.088616	加载进度：###### [50%]
# 2025-07-25 09:17:24.224292	加载进度：####### [60%]
# 2025-07-25 09:17:25.451736	加载进度：######## [70%]
# 2025-07-25 09:17:26.720665	加载进度：######### [80%]
# 2025-07-25 09:17:27.988965	加载进度：########## [90%]
# 2025-07-25 09:17:29.001179	加载进度：########## [100%]
# 2025-07-25 09:17:29.003316	历史数据加载完成，数据量：232800
# 2025-07-25 09:17:29.111658	策略初始化完成
# 2025-07-25 09:17:29.111658	开始回放历史数据
# 2025-07-25 09:17:30.049942	回放进度：= [0%]
# 2025-07-25 09:17:30.657245	回放进度：== [10%]
# 2025-07-25 09:17:31.271627	回放进度：=== [20%]
# 2025-07-25 09:17:31.877553	回放进度：==== [30%]
# 2025-07-25 09:17:32.485588	回放进度：===== [40%]
# 2025-07-25 09:17:33.064828	回放进度：====== [50%]
# 2025-07-25 09:17:33.688179	回放进度：======= [60%]
# ...

# %%
engine = BacktestingEngine()

engine.set_parameters(
    vt_symbol="IF99.CFFEX",
    interval="1m",
    start=datetime(2021, 1, 1),
    end=datetime(2023, 12, 31),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)

setting = {}
engine.add_strategy(AtrRsiDemo, setting)


setting = OptimizationSetting()

setting.set_target("sharpe_ratio")

#setting.add_parameter("atr_window", 10, 40, 2)
#setting.add_parameter("atr_ma_window", 10, 20, 2)
setting.add_parameter("rsi_window", 2, 20, 2)
setting.add_parameter("rsi_signal", 2, 20, 2)
#setting.add_parameter("trailing_percent", 0.1, 1.5, 0.1)

setting.add_parameter("atr_window", 36)
setting.add_parameter("atr_ma_window", 20)
#setting.add_parameter("rsi_window", 8)
#setting.add_parameter("rsi_signal", 10)
setting.add_parameter("trailing_percent", 0.7)

result = engine.run_bf_optimization(setting)
# Out:
# 2025-07-25 09:17:36.179759	开始执行穷举算法优化
# 2025-07-25 09:17:36.179759	参数优化空间：100
# 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# 2025-07-25 09:19:08.526329	穷举算法优化完成，耗时92秒
# 2025-07-25 09:19:10.699060	参数：{'rsi_window': 8, 'rsi_signal': 2, 'atr_window': 36, 'atr_ma_window': 20, 'trailing_percent': 0.7}, 目标：0.9214761174473598
# 2025-07-25 09:19:10.700061	参数：{'rsi_window': 8, 'rsi_signal': 4, 'atr_window': 36, 'atr_ma_window': 20, 'trailing_percent': 0.7}, 目标：0.9214761174473598
# 2025-07-25 09:19:10.700061	参数：{'rsi_window': 8, 'rsi_signal': 6, 'atr_window': 36, 'atr_ma_window': 20, 'trailing_percent': 0.7}, 目标：0.9214761174473598
# 2025-07-25 09:19:10.700061	参数：{'rsi_window': 8, 'rsi_signal': 8, 'atr_window': 36, 'atr_ma_window': 20, 'trailing_percent': 0.7}, 目标：0.9214761174473598
# 2025-07-25 09:19:10.700061	参数：{'rsi_window': 8, 'rsi_signal': 10, 'atr_window': 36, 'atr_ma_window': 20, 'trailing_percent': 0.7}, 目标：0.9214761174473598
# ...

# %%
engine = BacktestingEngine()

engine.set_parameters(
    vt_symbol="IF99.CFFEX",
    interval="1m",
    start=datetime(2021, 1, 1),
    end=datetime(2023, 12, 31),
    rate=0.3/10000,
    slippage=0.2,
    size=300,
    pricetick=0.2,
    capital=1_000_000,
)

setting = {}
engine.add_strategy(AtrRsiDemo, setting)


setting = OptimizationSetting()

setting.set_target("sharpe_ratio")

setting.add_parameter("atr_window", 10, 40, 2)
setting.add_parameter("atr_ma_window", 10, 20, 2)
setting.add_parameter("rsi_window", 2, 20, 2)
setting.add_parameter("rsi_signal", 2, 20, 2)
setting.add_parameter("trailing_percent", 0.1, 1.5, 0.1)

#setting.add_parameter("atr_window", 36)
#setting.add_parameter("atr_ma_window", 20)
#setting.add_parameter("rsi_window", 8)
#setting.add_parameter("rsi_signal", 10)
#setting.add_parameter("trailing_percent", 0.7)

result = engine.run_ga_optimization(setting)
# Out:
# 2025-07-25 09:19:11.640665	开始执行遗传算法优化
# 2025-07-25 09:19:11.641173	参数优化空间：134400
# 2025-07-25 09:19:11.641173	每代族群总数：100
# 2025-07-25 09:19:11.641173	优良筛选个数：80
# 2025-07-25 09:19:11.641173	迭代次数：30
# 2025-07-25 09:19:11.641173	交叉概率：95%
# 2025-07-25 09:19:11.641173	突变概率：5%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2025-07-25 09:33:39.483724	遗传算法优化完成，耗时867秒
# 2025-07-25 09:33:39.652414	参数：{'atr_window': 18, 'atr_ma_window': 18, 'rsi_window': 8, 'rsi_signal': 6, 'trailing_percent': 0.5}, 目标：1.5149739859162918
# 2025-07-25 09:33:39.652414	参数：{'atr_window': 18, 'atr_ma_window': 20, 'rsi_window': 8, 'rsi_signal': 6, 'trailing_percent': 0.5}, 目标：1.5149739859162918
# ...
