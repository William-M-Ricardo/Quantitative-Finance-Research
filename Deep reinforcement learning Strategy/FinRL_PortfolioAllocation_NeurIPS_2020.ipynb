# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_PortfolioAllocation_NeurIPS_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
import os

os.environ["HTTP_PROXY"] = "http://127.0.0.1:7899"
os.environ["HTTPS_PROXY"] = "http://127.0.0.1:7899"

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
sys.path.append("../FinRL-Library")
# Out:
# c:\Python311\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date = '2008-01-02',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER, time_interval='1D')
df.to_csv("data.csv")
# Out:
# YF.download() has changed argument auto_adjust default to True
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No Adj Close column found, existing columns are: Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume', 'tic'], dtype='object', name='Price')

# %%
# import pandas as pd
# df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    timestamp      close       high        low       open    volume  tic
# 0 2008-01-02  38.898693  39.874208  38.708163  39.698920   8053700  AXP
# 1 2008-01-03  38.418549  39.249261  38.258504  39.020625   7753200  AXP
# 2 2008-01-04  37.450680  38.098485  37.122967  38.098485   8501400  AXP
# 3 2008-01-07  37.618317  38.182285  37.031483  37.747876  14031100  AXP
# 4 2008-01-08  36.543739  37.877452  36.398934  37.877452  11721000  AXP

# %%
df.shape
# Out:
# (101615, 7)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# 目前Yahoo格式已经发生变化，需要额外做列名修改
df = df.rename(columns={"timestamp": "date"})
df
# Out:
#              date      close       high        low       open    volume  tic
# 0      2008-01-02  38.898693  39.874208  38.708163  39.698920   8053700  AXP
# 1      2008-01-03  38.418549  39.249261  38.258504  39.020625   7753200  AXP
# 2      2008-01-04  37.450680  38.098485  37.122967  38.098485   8501400  AXP
# 3      2008-01-07  37.618317  38.182285  37.031483  37.747876  14031100  AXP
# 4      2008-01-08  36.543739  37.877452  36.398934  37.877452  11721000  AXP
# ...           ...        ...        ...        ...        ...       ...  ...
# 101610 2021-10-25  47.539948  48.207985  47.458975  47.969113   6293200  DOW
# 101611 2021-10-26  47.539948  48.390176  47.110785  47.539948   6875200  DOW
# 101612 2021-10-27  45.345547  47.434682  45.264574  47.434682  11512700  DOW
# 101613 2021-10-28  45.807102  46.041928  45.515595  45.547985   5974400  DOW
# 101614 2021-10-29  45.321255  45.871879  45.070234  45.450813   5894900  DOW
#
# [101615 rows x 7 columns]

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators

# %%
df.shape
# Out:
# (97524, 15)

# %%
df.head()
# Out:
#             date      close       high        low       open      volume  \
# 0     2008-01-02   5.855757   6.018651   5.786934   5.988898  1079178800
# 3483  2008-01-02  32.223785  32.528046  31.988676  32.223785     7934400
# 6966  2008-01-02  38.898693  39.874208  38.708163  39.698920     8053700
# 10449 2008-01-02  63.481602  64.375704  63.027217  64.177830     4303000
# 13932 2008-01-02  44.507298  45.792798  44.141816  45.723482     6337800
#
#         tic  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0      AAPL   0.0  5.860936  5.853284   100.0 -66.666667  100.0      5.855757
# 3483   AMGN   0.0  5.860936  5.853284   100.0 -66.666667  100.0     32.223785
# 6966    AXP   0.0  5.860936  5.853284   100.0 -66.666667  100.0     38.898693
# 10449    BA   0.0  5.860936  5.853284   100.0 -66.666667  100.0     63.481602
# 13932   CAT   0.0  5.860936  5.853284   100.0 -66.666667  100.0     44.507298
#
#        close_60_sma
# 0          5.855757
# 3483      32.223785
# 6966      38.898693
# 10449     63.481602
# 13932     44.507298

# %% [markdown]
# ## Add covariance matrix as states

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values 
  cov_list.append(covs)

  
df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (90468, 17)

# %%
df.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2008-12-31   2.565124   2.636954   2.564824   2.583758  607541200  AAPL
# 1 2008-12-31  39.933990  40.258995  39.456858  39.491432    6287200  AMGN
# 2 2008-12-31  14.326869  14.481337  13.832573  13.878913    9625600   AXP
# 3 2008-12-31  32.005898  32.290929  31.128306  31.195813    5443100    BA
# 4 2008-12-31  28.895693  29.173847  28.268230  28.268230    6277400   CAT
#
#        macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0 -0.082003   3.071161   2.436449  42.254777  -80.847278  21.092396
# 1  0.149617  40.761994  38.992589  51.060606   51.895127   8.496588
# 2 -0.919292  18.322188  12.440032  42.554852  -74.811701  24.562341
# 3 -0.279800  32.174385  28.867837  47.440252  157.923151  10.291957
# 4  0.639824  29.617316  24.842692  51.205310   98.904627   9.153607
#
#    close_30_sma  close_60_sma  \
# 0      2.729571      2.840867
# 1     39.188098     38.754529
# 2     15.469929     17.309638
# 3     30.327214     32.389917
# 4     26.046878     25.787324
#
#                                             cov_list  \
# 0  [[0.001348969454281321, 0.00042841305258196536...
# 1  [[0.001348969454281321, 0.00042841305258196536...
# 2  [[0.001348969454281321, 0.00042841305258196536...
# 3  [[0.001348969454281321, 0.00042841305258196536...
# 4  [[0.001348969454281321, 0.00042841305258196536...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2009-01-01','2020-07-01')
#trade = data_split(df, '2020-01-01', config.END_DATE)

# %%
train.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2009-01-02   2.727417   2.736133   2.559414   2.581053  746015200  AAPL
# 0 2009-01-02  40.791439  40.853674  39.933981  40.514839    6547900  AMGN
# 0 2009-01-02  14.929288  15.076032  14.211014  14.342311   10955700   AXP
# 0 2009-01-02  33.941097  34.173623  32.088400  32.103402    7010200    BA
# 0 2009-01-02  30.344688  30.389969  28.921573  29.050948    7117200   CAT
#
#        macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0 -0.069643   3.057737   2.434395  45.440190  -30.508971  15.275059
# 0  0.221588  40.900954  38.958735  52.756832   94.548737   4.736024
# 0 -0.817562  18.141770  12.424276  43.957547  -42.019082  20.860417
# 0 -0.002008  32.948628  28.452131  50.822035  275.696378   2.023480
# 0  0.813121  30.107328  24.822308  53.661261  131.676166  13.753017
#
#    close_30_sma  close_60_sma  \
# 0      2.730413      2.841663
# 0     39.249180     38.838661
# 0     15.468642     17.194817
# 0     30.469480     32.344132
# 0     26.278027     25.787891
#
#                                             cov_list  \
# 0  [[0.0013661510786399586, 0.0004339385349021332...
# 0  [[0.0013661510786399586, 0.0004339385349021332...
# 0  [[0.0013661510786399586, 0.0004339385349021332...
# 0  [[0.0013661510786399586, 0.0004339385349021332...
# 0  [[0.0013661510786399586, 0.0004339385349021332...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...
# 0  tic             AAPL      AMGN       AXP      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd

# from gym.utils import seeding
# import gym
# from gym import spaces

# 使用gymnasium替换gym
from gymnasium.utils import seeding
import gymnasium as gym
from gymnasium import spaces

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then 
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step
        

    """
    metadata = {'render.modes': ['human']}

    def __init__(self, 
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,)) 
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False     
        self.turbulence_threshold = turbulence_threshold        
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]

        
    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()
            
            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))           
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")
            
            # 补充额外返回值
            # return self.state, self.reward, self.terminal,{}
            return self.state, self.reward, self.terminal, False, {}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions) 
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])            
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value 
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        # 补充额外返回值
        # return self.state, self.reward, self.terminal, {}
        return self.state, self.reward, self.terminal, False, {}

    # 新版本兼容修改
    # def reset(self):

    def reset(self, seed: int = 0):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False 
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]] 

        # 补充额外返回值
        # return self.state
        return self.state, {}
    
    def render(self, mode='human'):
        return self.state
        
    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output

    
    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']
        
        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 28, State Space: 28

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# ----------------------------------------
# | time/                 |              |
# |    fps                | 386          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -39.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 99           |
# |    policy_loss        | 1.98e+08     |
# |    reward             | 1.635395e+06 |
# |    std                | 0.997        |
# |    value_loss         | 2.82e+13     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 404           |
# |    iterations         | 200           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -39.7         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 199           |
# |    policy_loss        | 2.47e+08      |
# |    reward             | 2.0924836e+06 |
# |    std                | 0.997         |
# |    value_loss         | 4.65e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 412           |
# |    iterations         | 300           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 1500          |
# | train/                |               |
# |    entropy_loss       | -39.6         |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 299           |
# |    policy_loss        | 3.9e+08       |
# |    reward             | 3.2148472e+06 |
# |    std                | 0.997         |
# |    value_loss         | 1.15e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 411           |
# |    iterations         | 400           |
# |    time_elapsed       | 4             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -39.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 399           |
# |    policy_loss        | 4.52e+08      |
# |    reward             | 4.0730552e+06 |
# |    std                | 0.995         |
# |    value_loss         | 1.67e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 408          |
# |    iterations         | 500          |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -39.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 499          |
# |    policy_loss        | 6.82e+08     |
# |    reward             | 5.491502e+06 |
# |    std                | 0.994        |
# |    value_loss         | 3.35e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6316970.127903927
# Sharpe:  0.9699628402094997
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 401           |
# |    iterations         | 600           |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -39.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 599           |
# |    policy_loss        | 1.24e+08      |
# |    reward             | 1.0829619e+06 |
# |    std                | 0.994         |
# |    value_loss         | 1.17e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 395           |
# |    iterations         | 700           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -39.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 699           |
# |    policy_loss        | 1.91e+08      |
# |    reward             | 1.6575949e+06 |
# |    std                | 0.994         |
# |    value_loss         | 3.01e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 395           |
# |    iterations         | 800           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | 1.79e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 799           |
# |    policy_loss        | 2.74e+08      |
# |    reward             | 2.3674988e+06 |
# |    std                | 0.993         |
# |    value_loss         | 6.03e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 393           |
# |    iterations         | 900           |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 899           |
# |    policy_loss        | 3.9e+08       |
# |    reward             | 3.3109508e+06 |
# |    std                | 0.993         |
# |    value_loss         | 1.15e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 393           |
# |    iterations         | 1000          |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 999           |
# |    policy_loss        | 4.64e+08      |
# |    reward             | 4.0278058e+06 |
# |    std                | 0.992         |
# |    value_loss         | 1.79e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 380          |
# |    iterations         | 1100         |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -39.5        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 1099         |
# |    policy_loss        | 6.6e+08      |
# |    reward             | 5.500514e+06 |
# |    std                | 0.991        |
# |    value_loss         | 3.42e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5941151.243205708
# Sharpe:  0.9426072510013914
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 367           |
# |    iterations         | 1200          |
# |    time_elapsed       | 16            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | 1.79e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1199          |
# |    policy_loss        | 1.53e+08      |
# |    reward             | 1.2627321e+06 |
# |    std                | 0.992         |
# |    value_loss         | 1.62e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 368           |
# |    iterations         | 1300          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1299          |
# |    policy_loss        | 2e+08         |
# |    reward             | 1.6837074e+06 |
# |    std                | 0.992         |
# |    value_loss         | 3.07e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 371           |
# |    iterations         | 1400          |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1399          |
# |    policy_loss        | 3.04e+08      |
# |    reward             | 2.6605548e+06 |
# |    std                | 0.991         |
# |    value_loss         | 7.35e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 372           |
# |    iterations         | 1500          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -39.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1499          |
# |    policy_loss        | 3.71e+08      |
# |    reward             | 3.4168125e+06 |
# |    std                | 0.991         |
# |    value_loss         | 1.17e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 371          |
# |    iterations         | 1600         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -39.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 1599         |
# |    policy_loss        | 5.03e+08     |
# |    reward             | 4.445672e+06 |
# |    std                | 0.99         |
# |    value_loss         | 2.06e+14     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 372           |
# |    iterations         | 1700          |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -39.4         |
# |    explained_variance | 2.38e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1699          |
# |    policy_loss        | 6.85e+08      |
# |    reward             | 5.6539435e+06 |
# |    std                | 0.99          |
# |    value_loss         | 3.22e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5691526.442251616
# Sharpe:  0.9173550083569351
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 373           |
# |    iterations         | 1800          |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -39.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1799          |
# |    policy_loss        | 1.67e+08      |
# |    reward             | 1.4895655e+06 |
# |    std                | 0.99          |
# |    value_loss         | 2.25e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 374           |
# |    iterations         | 1900          |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -39.4         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1899          |
# |    policy_loss        | 2.38e+08      |
# |    reward             | 1.9931169e+06 |
# |    std                | 0.989         |
# |    value_loss         | 4.26e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 376          |
# |    iterations         | 2000         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -39.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 1999         |
# |    policy_loss        | 3.16e+08     |
# |    reward             | 2.890143e+06 |
# |    std                | 0.988        |
# |    value_loss         | 8.61e+13     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 376           |
# |    iterations         | 2100          |
# |    time_elapsed       | 27            |
# |    total_timesteps    | 10500         |
# | train/                |               |
# |    entropy_loss       | -39.4         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2099          |
# |    policy_loss        | 4.04e+08      |
# |    reward             | 3.5432858e+06 |
# |    std                | 0.987         |
# |    value_loss         | 1.33e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 375          |
# |    iterations         | 2200         |
# |    time_elapsed       | 29           |
# |    total_timesteps    | 11000        |
# | train/                |              |
# |    entropy_loss       | -39.4        |
# |    explained_variance | 1.79e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2199         |
# |    policy_loss        | 5.69e+08     |
# |    reward             | 4.860806e+06 |
# |    std                | 0.987        |
# |    value_loss         | 2.85e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 376          |
# |    iterations         | 2300         |
# |    time_elapsed       | 30           |
# |    total_timesteps    | 11500        |
# | train/                |              |
# |    entropy_loss       | -39.3        |
# |    explained_variance | -2.38e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2299         |
# |    policy_loss        | 6.55e+08     |
# |    reward             | 4.893532e+06 |
# |    std                | 0.986        |
# |    value_loss         | 3.25e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6312244.680953106
# Sharpe:  0.9631214960937231
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 376           |
# |    iterations         | 2400          |
# |    time_elapsed       | 31            |
# |    total_timesteps    | 12000         |
# | train/                |               |
# |    entropy_loss       | -39.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2399          |
# |    policy_loss        | 1.77e+08      |
# |    reward             | 1.5180821e+06 |
# |    std                | 0.986         |
# |    value_loss         | 2.34e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 371           |
# |    iterations         | 2500          |
# |    time_elapsed       | 33            |
# |    total_timesteps    | 12500         |
# | train/                |               |
# |    entropy_loss       | -39.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2499          |
# |    policy_loss        | 2.42e+08      |
# |    reward             | 2.1378418e+06 |
# |    std                | 0.986         |
# |    value_loss         | 4.72e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 370          |
# |    iterations         | 2600         |
# |    time_elapsed       | 35           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -39.3        |
# |    explained_variance | 2.38e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2599         |
# |    policy_loss        | 3.58e+08     |
# |    reward             | 3.185391e+06 |
# |    std                | 0.985        |
# |    value_loss         | 1.06e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 372          |
# |    iterations         | 2700         |
# |    time_elapsed       | 36           |
# |    total_timesteps    | 13500        |
# | train/                |              |
# |    entropy_loss       | -39.3        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2699         |
# |    policy_loss        | 4.56e+08     |
# |    reward             | 3.786318e+06 |
# |    std                | 0.985        |
# |    value_loss         | 1.54e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 373          |
# |    iterations         | 2800         |
# |    time_elapsed       | 37           |
# |    total_timesteps    | 14000        |
# | train/                |              |
# |    entropy_loss       | -39.3        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2799         |
# |    policy_loss        | 6.8e+08      |
# |    reward             | 5.693635e+06 |
# |    std                | 0.984        |
# |    value_loss         | 3.34e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6118991.058531033
# Sharpe:  0.9446133203445978
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 2900      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -39.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.08e+08  |
# |    reward             | 867529.4  |
# |    std                | 0.983     |
# |    value_loss         | 8.87e+12  |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 375           |
# |    iterations         | 3000          |
# |    time_elapsed       | 39            |
# |    total_timesteps    | 15000         |
# | train/                |               |
# |    entropy_loss       | -39.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2999          |
# |    policy_loss        | 2.15e+08      |
# |    reward             | 1.7678124e+06 |
# |    std                | 0.984         |
# |    value_loss         | 3.34e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 375          |
# |    iterations         | 3100         |
# |    time_elapsed       | 41           |
# |    total_timesteps    | 15500        |
# | train/                |              |
# |    entropy_loss       | -39.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 3099         |
# |    policy_loss        | 2.54e+08     |
# |    reward             | 2.311066e+06 |
# |    std                | 0.983        |
# |    value_loss         | 5.6e+13      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 376          |
# |    iterations         | 3200         |
# |    time_elapsed       | 42           |
# |    total_timesteps    | 16000        |
# | train/                |              |
# |    entropy_loss       | -39.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 3199         |
# |    policy_loss        | 3.83e+08     |
# |    reward             | 3.345315e+06 |
# |    std                | 0.982        |
# |    value_loss         | 1.15e+14     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 378           |
# |    iterations         | 3300          |
# |    time_elapsed       | 43            |
# |    total_timesteps    | 16500         |
# | train/                |               |
# |    entropy_loss       | -39.2         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3299          |
# |    policy_loss        | 4.45e+08      |
# |    reward             | 4.0380508e+06 |
# |    std                | 0.982         |
# |    value_loss         | 1.74e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 379          |
# |    iterations         | 3400         |
# |    time_elapsed       | 44           |
# |    total_timesteps    | 17000        |
# | train/                |              |
# |    entropy_loss       | -39.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 3399         |
# |    policy_loss        | 5.94e+08     |
# |    reward             | 5.446342e+06 |
# |    std                | 0.981        |
# |    value_loss         | 3.07e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6308518.392393811
# Sharpe:  0.9668098675600545
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 379           |
# |    iterations         | 3500          |
# |    time_elapsed       | 46            |
# |    total_timesteps    | 17500         |
# | train/                |               |
# |    entropy_loss       | -39.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3499          |
# |    policy_loss        | 1.23e+08      |
# |    reward             | 1.1558529e+06 |
# |    std                | 0.98          |
# |    value_loss         | 1.31e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 380           |
# |    iterations         | 3600          |
# |    time_elapsed       | 47            |
# |    total_timesteps    | 18000         |
# | train/                |               |
# |    entropy_loss       | -39.2         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3599          |
# |    policy_loss        | 2.2e+08       |
# |    reward             | 1.7980856e+06 |
# |    std                | 0.98          |
# |    value_loss         | 3.35e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 382           |
# |    iterations         | 3700          |
# |    time_elapsed       | 48            |
# |    total_timesteps    | 18500         |
# | train/                |               |
# |    entropy_loss       | -39.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3699          |
# |    policy_loss        | 2.83e+08      |
# |    reward             | 2.4880172e+06 |
# |    std                | 0.98          |
# |    value_loss         | 6.35e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 383           |
# |    iterations         | 3800          |
# |    time_elapsed       | 49            |
# |    total_timesteps    | 19000         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3799          |
# |    policy_loss        | 3.73e+08      |
# |    reward             | 3.4441445e+06 |
# |    std                | 0.979         |
# |    value_loss         | 1.21e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 383           |
# |    iterations         | 3900          |
# |    time_elapsed       | 50            |
# |    total_timesteps    | 19500         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 2.38e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3899          |
# |    policy_loss        | 4.77e+08      |
# |    reward             | 4.3263815e+06 |
# |    std                | 0.979         |
# |    value_loss         | 1.97e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 384           |
# |    iterations         | 4000          |
# |    time_elapsed       | 51            |
# |    total_timesteps    | 20000         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3999          |
# |    policy_loss        | 7.19e+08      |
# |    reward             | 5.9772825e+06 |
# |    std                | 0.979         |
# |    value_loss         | 3.68e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6047032.982339709
# Sharpe:  0.942948595137113
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 384           |
# |    iterations         | 4100          |
# |    time_elapsed       | 53            |
# |    total_timesteps    | 20500         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4099          |
# |    policy_loss        | 1.69e+08      |
# |    reward             | 1.4739894e+06 |
# |    std                | 0.979         |
# |    value_loss         | 2.24e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 385           |
# |    iterations         | 4200          |
# |    time_elapsed       | 54            |
# |    total_timesteps    | 21000         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4199          |
# |    policy_loss        | 2.19e+08      |
# |    reward             | 1.8770898e+06 |
# |    std                | 0.978         |
# |    value_loss         | 3.69e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 386           |
# |    iterations         | 4300          |
# |    time_elapsed       | 55            |
# |    total_timesteps    | 21500         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4299          |
# |    policy_loss        | 3.49e+08      |
# |    reward             | 2.9656628e+06 |
# |    std                | 0.978         |
# |    value_loss         | 9.39e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 386          |
# |    iterations         | 4400         |
# |    time_elapsed       | 56           |
# |    total_timesteps    | 22000        |
# | train/                |              |
# |    entropy_loss       | -39.1        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 4399         |
# |    policy_loss        | 3.94e+08     |
# |    reward             | 3.576039e+06 |
# |    std                | 0.977        |
# |    value_loss         | 1.42e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 387          |
# |    iterations         | 4500         |
# |    time_elapsed       | 58           |
# |    total_timesteps    | 22500        |
# | train/                |              |
# |    entropy_loss       | -39.1        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 4499         |
# |    policy_loss        | 5.98e+08     |
# |    reward             | 5.206098e+06 |
# |    std                | 0.976        |
# |    value_loss         | 2.86e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 388          |
# |    iterations         | 4600         |
# |    time_elapsed       | 59           |
# |    total_timesteps    | 23000        |
# | train/                |              |
# |    entropy_loss       | -39.1        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 4599         |
# |    policy_loss        | 7.91e+08     |
# |    reward             | 6.841511e+06 |
# |    std                | 0.977        |
# |    value_loss         | 5.08e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6906537.11684431
# Sharpe:  1.010020599813391
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 388           |
# |    iterations         | 4700          |
# |    time_elapsed       | 60            |
# |    total_timesteps    | 23500         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4699          |
# |    policy_loss        | 1.52e+08      |
# |    reward             | 1.4588362e+06 |
# |    std                | 0.976         |
# |    value_loss         | 2.13e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 389           |
# |    iterations         | 4800          |
# |    time_elapsed       | 61            |
# |    total_timesteps    | 24000         |
# | train/                |               |
# |    entropy_loss       | -39.1         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4799          |
# |    policy_loss        | 2.11e+08      |
# |    reward             | 1.9753442e+06 |
# |    std                | 0.976         |
# |    value_loss         | 4.14e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 389           |
# |    iterations         | 4900          |
# |    time_elapsed       | 62            |
# |    total_timesteps    | 24500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4899          |
# |    policy_loss        | 3.56e+08      |
# |    reward             | 3.0599368e+06 |
# |    std                | 0.976         |
# |    value_loss         | 9.7e+13       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 389           |
# |    iterations         | 5000          |
# |    time_elapsed       | 64            |
# |    total_timesteps    | 25000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4999          |
# |    policy_loss        | 4.3e+08       |
# |    reward             | 3.6056652e+06 |
# |    std                | 0.976         |
# |    value_loss         | 1.42e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 390          |
# |    iterations         | 5100         |
# |    time_elapsed       | 65           |
# |    total_timesteps    | 25500        |
# | train/                |              |
# |    entropy_loss       | -39          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 5099         |
# |    policy_loss        | 6.21e+08     |
# |    reward             | 5.451391e+06 |
# |    std                | 0.976        |
# |    value_loss         | 3e+14        |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 390           |
# |    iterations         | 5200          |
# |    time_elapsed       | 66            |
# |    total_timesteps    | 26000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5199          |
# |    policy_loss        | 7.23e+08      |
# |    reward             | 6.2595745e+06 |
# |    std                | 0.975         |
# |    value_loss         | 4.09e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6656237.7464150945
# Sharpe:  0.9925028795668609
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 390           |
# |    iterations         | 5300          |
# |    time_elapsed       | 67            |
# |    total_timesteps    | 26500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 2.38e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5299          |
# |    policy_loss        | 1.87e+08      |
# |    reward             | 1.5745404e+06 |
# |    std                | 0.976         |
# |    value_loss         | 2.57e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 391           |
# |    iterations         | 5400          |
# |    time_elapsed       | 68            |
# |    total_timesteps    | 27000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5399          |
# |    policy_loss        | 2.57e+08      |
# |    reward             | 2.1052212e+06 |
# |    std                | 0.975         |
# |    value_loss         | 5.02e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 391           |
# |    iterations         | 5500          |
# |    time_elapsed       | 70            |
# |    total_timesteps    | 27500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5499          |
# |    policy_loss        | 3.71e+08      |
# |    reward             | 3.1904162e+06 |
# |    std                | 0.975         |
# |    value_loss         | 9.95e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 391           |
# |    iterations         | 5600          |
# |    time_elapsed       | 71            |
# |    total_timesteps    | 28000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5599          |
# |    policy_loss        | 4.14e+08      |
# |    reward             | 3.7784188e+06 |
# |    std                | 0.975         |
# |    value_loss         | 1.53e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 392          |
# |    iterations         | 5700         |
# |    time_elapsed       | 72           |
# |    total_timesteps    | 28500        |
# | train/                |              |
# |    entropy_loss       | -39          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 5699         |
# |    policy_loss        | 6.74e+08     |
# |    reward             | 5.490041e+06 |
# |    std                | 0.975        |
# |    value_loss         | 3.53e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6212011.63807217
# Sharpe:  0.9582571749765455
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 5800     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -39      |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5799     |
# |    policy_loss        | 1.11e+08 |
# |    reward             | 985968.7 |
# |    std                | 0.974    |
# |    value_loss         | 9.66e+12 |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 392           |
# |    iterations         | 5900          |
# |    time_elapsed       | 75            |
# |    total_timesteps    | 29500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5899          |
# |    policy_loss        | 2.04e+08      |
# |    reward             | 1.6947666e+06 |
# |    std                | 0.974         |
# |    value_loss         | 3e+13         |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 392           |
# |    iterations         | 6000          |
# |    time_elapsed       | 76            |
# |    total_timesteps    | 30000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5999          |
# |    policy_loss        | 2.56e+08      |
# |    reward             | 2.3534168e+06 |
# |    std                | 0.974         |
# |    value_loss         | 5.89e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 393           |
# |    iterations         | 6100          |
# |    time_elapsed       | 77            |
# |    total_timesteps    | 30500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6099          |
# |    policy_loss        | 4.23e+08      |
# |    reward             | 3.3880718e+06 |
# |    std                | 0.973         |
# |    value_loss         | 1.26e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 393           |
# |    iterations         | 6200          |
# |    time_elapsed       | 78            |
# |    total_timesteps    | 31000         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6199          |
# |    policy_loss        | 5.18e+08      |
# |    reward             | 4.2763065e+06 |
# |    std                | 0.973         |
# |    value_loss         | 2e+14         |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 394           |
# |    iterations         | 6300          |
# |    time_elapsed       | 79            |
# |    total_timesteps    | 31500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6299          |
# |    policy_loss        | 6.54e+08      |
# |    reward             | 5.8038475e+06 |
# |    std                | 0.973         |
# |    value_loss         | 3.47e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6058420.63169845
# Sharpe:  0.9503522505048146
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 394          |
# |    iterations         | 6400         |
# |    time_elapsed       | 81           |
# |    total_timesteps    | 32000        |
# | train/                |              |
# |    entropy_loss       | -39          |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 6399         |
# |    policy_loss        | 1.4e+08      |
# |    reward             | 1.277682e+06 |
# |    std                | 0.973        |
# |    value_loss         | 1.61e+13     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 394           |
# |    iterations         | 6500          |
# |    time_elapsed       | 82            |
# |    total_timesteps    | 32500         |
# | train/                |               |
# |    entropy_loss       | -39           |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6499          |
# |    policy_loss        | 1.93e+08      |
# |    reward             | 1.6164001e+06 |
# |    std                | 0.973         |
# |    value_loss         | 3.02e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 394          |
# |    iterations         | 6600         |
# |    time_elapsed       | 83           |
# |    total_timesteps    | 33000        |
# | train/                |              |
# |    entropy_loss       | -39          |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 6599         |
# |    policy_loss        | 2.97e+08     |
# |    reward             | 2.608474e+06 |
# |    std                | 0.973        |
# |    value_loss         | 7.15e+13     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 394           |
# |    iterations         | 6700          |
# |    time_elapsed       | 84            |
# |    total_timesteps    | 33500         |
# | train/                |               |
# |    entropy_loss       | -38.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6699          |
# |    policy_loss        | 3.81e+08      |
# |    reward             | 3.2448735e+06 |
# |    std                | 0.972         |
# |    value_loss         | 1.15e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 395          |
# |    iterations         | 6800         |
# |    time_elapsed       | 86           |
# |    total_timesteps    | 34000        |
# | train/                |              |
# |    entropy_loss       | -38.9        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 6799         |
# |    policy_loss        | 4.99e+08     |
# |    reward             | 4.655594e+06 |
# |    std                | 0.972        |
# |    value_loss         | 2.3e+14      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 395           |
# |    iterations         | 6900          |
# |    time_elapsed       | 87            |
# |    total_timesteps    | 34500         |
# | train/                |               |
# |    entropy_loss       | -38.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 6899          |
# |    policy_loss        | 7.44e+08      |
# |    reward             | 6.2758075e+06 |
# |    std                | 0.971         |
# |    value_loss         | 4.09e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6512569.764282657
# Sharpe:  0.9806485707962405
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 395           |
# |    iterations         | 7000          |
# |    time_elapsed       | 88            |
# ...
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 7800          |
# |    time_elapsed       | 98            |
# |    total_timesteps    | 39000         |
# | train/                |               |
# |    entropy_loss       | -38.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 7799          |
# |    policy_loss        | 3.68e+08      |
# |    reward             | 3.0462875e+06 |
# |    std                | 0.967         |
# |    value_loss         | 9.84e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 7900          |
# |    time_elapsed       | 99            |
# |    total_timesteps    | 39500         |
# | train/                |               |
# |    entropy_loss       | -38.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 7899          |
# |    policy_loss        | 3.79e+08      |
# |    reward             | 3.5966442e+06 |
# |    std                | 0.966         |
# |    value_loss         | 1.28e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 8000          |
# |    time_elapsed       | 100           |
# |    total_timesteps    | 40000         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | 1.79e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 7999          |
# |    policy_loss        | 5.76e+08      |
# |    reward             | 5.1122785e+06 |
# |    std                | 0.966         |
# |    value_loss         | 2.85e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 397          |
# |    iterations         | 8100         |
# |    time_elapsed       | 101          |
# |    total_timesteps    | 40500        |
# | train/                |              |
# |    entropy_loss       | -38.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 8099         |
# |    policy_loss        | 7.72e+08     |
# |    reward             | 6.416165e+06 |
# |    std                | 0.965        |
# |    value_loss         | 4.56e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6492803.334355086
# Sharpe:  0.9766555479324195
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 8200          |
# |    time_elapsed       | 103           |
# |    total_timesteps    | 41000         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8199          |
# |    policy_loss        | 1.99e+08      |
# |    reward             | 1.6725251e+06 |
# |    std                | 0.965         |
# |    value_loss         | 2.96e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 8300          |
# |    time_elapsed       | 104           |
# |    total_timesteps    | 41500         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8299          |
# |    policy_loss        | 2.45e+08      |
# |    reward             | 2.1534835e+06 |
# |    std                | 0.964         |
# |    value_loss         | 4.88e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 8400          |
# |    time_elapsed       | 105           |
# |    total_timesteps    | 42000         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8399          |
# |    policy_loss        | 3.6e+08       |
# |    reward             | 3.1361218e+06 |
# |    std                | 0.963         |
# |    value_loss         | 1.13e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 8500          |
# |    time_elapsed       | 106           |
# |    total_timesteps    | 42500         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8499          |
# |    policy_loss        | 4.14e+08      |
# |    reward             | 3.7379205e+06 |
# |    std                | 0.963         |
# |    value_loss         | 1.44e+14      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 8600          |
# |    time_elapsed       | 108           |
# |    total_timesteps    | 43000         |
# | train/                |               |
# |    entropy_loss       | -38.7         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8599          |
# |    policy_loss        | 6.17e+08      |
# |    reward             | 5.2823375e+06 |
# |    std                | 0.963         |
# |    value_loss         | 2.87e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6022867.438485057
# Sharpe:  0.9452368187959016
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 397          |
# |    iterations         | 8700         |
# |    time_elapsed       | 109          |
# |    total_timesteps    | 43500        |
# | train/                |              |
# |    entropy_loss       | -38.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 8699         |
# |    policy_loss        | 1.09e+08     |
# |    reward             | 1.067791e+06 |
# |    std                | 0.962        |
# |    value_loss         | 1.1e+13      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 396           |
# |    iterations         | 8800          |
# |    time_elapsed       | 110           |
# |    total_timesteps    | 44000         |
# | train/                |               |
# |    entropy_loss       | -38.6         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8799          |
# |    policy_loss        | 2.25e+08      |
# |    reward             | 1.8196476e+06 |
# |    std                | 0.962         |
# |    value_loss         | 3.59e+13      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 397          |
# |    iterations         | 8900         |
# |    time_elapsed       | 112          |
# |    total_timesteps    | 44500        |
# | train/                |              |
# |    entropy_loss       | -38.6        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 8899         |
# |    policy_loss        | 2.79e+08     |
# |    reward             | 2.505234e+06 |
# |    std                | 0.961        |
# |    value_loss         | 6.66e+13     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 9000          |
# |    time_elapsed       | 113           |
# |    total_timesteps    | 45000         |
# | train/                |               |
# |    entropy_loss       | -38.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8999          |
# |    policy_loss        | 3.98e+08      |
# |    reward             | 3.4371992e+06 |
# |    std                | 0.961         |
# |    value_loss         | 1.23e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 397          |
# |    iterations         | 9100         |
# |    time_elapsed       | 114          |
# |    total_timesteps    | 45500        |
# | train/                |              |
# |    entropy_loss       | -38.6        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 9099         |
# |    policy_loss        | 4.84e+08     |
# |    reward             | 4.323622e+06 |
# |    std                | 0.96         |
# |    value_loss         | 1.99e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 397          |
# |    iterations         | 9200         |
# |    time_elapsed       | 115          |
# |    total_timesteps    | 46000        |
# | train/                |              |
# |    entropy_loss       | -38.6        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 9199         |
# |    policy_loss        | 6.78e+08     |
# |    reward             | 5.967298e+06 |
# |    std                | 0.959        |
# |    value_loss         | 3.91e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6512774.711755119
# Sharpe:  0.9781916003359872
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 9300          |
# |    time_elapsed       | 116           |
# |    total_timesteps    | 46500         |
# | train/                |               |
# |    entropy_loss       | -38.6         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9299          |
# |    policy_loss        | 1.54e+08      |
# |    reward             | 1.2849736e+06 |
# |    std                | 0.959         |
# |    value_loss         | 1.77e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 9400          |
# |    time_elapsed       | 118           |
# |    total_timesteps    | 47000         |
# | train/                |               |
# |    entropy_loss       | -38.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9399          |
# |    policy_loss        | 1.83e+08      |
# |    reward             | 1.8585134e+06 |
# |    std                | 0.959         |
# |    value_loss         | 3.33e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 397           |
# |    iterations         | 9500          |
# |    time_elapsed       | 119           |
# |    total_timesteps    | 47500         |
# | train/                |               |
# |    entropy_loss       | -38.5         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9499          |
# |    policy_loss        | 3.15e+08      |
# |    reward             | 2.7412732e+06 |
# |    std                | 0.959         |
# |    value_loss         | 7.8e+13       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 398           |
# |    iterations         | 9600          |
# |    time_elapsed       | 120           |
# |    total_timesteps    | 48000         |
# | train/                |               |
# |    entropy_loss       | -38.5         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9599          |
# |    policy_loss        | 3.83e+08      |
# |    reward             | 3.3188678e+06 |
# |    std                | 0.959         |
# |    value_loss         | 1.17e+14      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 398          |
# |    iterations         | 9700         |
# |    time_elapsed       | 121          |
# |    total_timesteps    | 48500        |
# | train/                |              |
# |    entropy_loss       | -38.5        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 9699         |
# |    policy_loss        | 5.01e+08     |
# |    reward             | 4.541135e+06 |
# |    std                | 0.958        |
# |    value_loss         | 2.17e+14     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 398          |
# |    iterations         | 9800         |
# |    time_elapsed       | 123          |
# |    total_timesteps    | 49000        |
# | train/                |              |
# |    entropy_loss       | -38.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 9799         |
# |    policy_loss        | 7.01e+08     |
# |    reward             | 5.892023e+06 |
# |    std                | 0.958        |
# |    value_loss         | 3.6e+14      |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6193338.14199379
# Sharpe:  0.9578294780992624
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 398           |
# |    iterations         | 9900          |
# |    time_elapsed       | 124           |
# |    total_timesteps    | 49500         |
# | train/                |               |
# |    entropy_loss       | -38.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9899          |
# |    policy_loss        | 1.61e+08      |
# |    reward             | 1.4904441e+06 |
# |    std                | 0.957         |
# |    value_loss         | 2.32e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 398           |
# |    iterations         | 10000         |
# |    time_elapsed       | 125           |
# |    total_timesteps    | 50000         |
# | train/                |               |
# |    entropy_loss       | -38.5         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9999          |
# |    policy_loss        | 2.29e+08      |
# |    reward             | 2.0621385e+06 |
# |    std                | 0.958         |
# |    value_loss         | 4.5e+13       |
# -----------------------------------------

# %%
trained_a2c.save('/content/trained_models/trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
# agent = DRLAgent(env = env_train)
# PPO_PARAMS = {
#     "n_steps": 2048,
#     "ent_coef": 0.005,
#     "learning_rate": 0.0001,
#     "batch_size": 128,
# }
# model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

# %%
# trained_ppo = agent.train_model(model=model_ppo, 
#                              tb_log_name='ppo',
#                              total_timesteps=80000)

# %%
# trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
# agent = DRLAgent(env = env_train)
# DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


# model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)

# %%
# trained_ddpg = agent.train_model(model=model_ddpg, 
#                              tb_log_name='ddpg',
#                              total_timesteps=50000)

# %%
# trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
# agent = DRLAgent(env = env_train)
# SAC_PARAMS = {
#     "batch_size": 128,
#     "buffer_size": 100000,
#     "learning_rate": 0.0003,
#     "learning_starts": 100,cur
#     "ent_coef": "auto_0.1",
# }

# model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

# %%
# trained_sac = agent.train_model(model=model_sac, 
#                              tb_log_name='sac',
#                              total_timesteps=50000)

# %%
# trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
# agent = DRLAgent(env = env_train)
# TD3_PARAMS = {"batch_size": 100, 
#               "buffer_size": 1000000, 
#               "learning_rate": 0.001}

# model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

# %%
# trained_td3 = agent.train_model(model=model_td3, 
#                              tb_log_name='td3',
#                              total_timesteps=30000)

# %%
# trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df,'2020-07-01', '2021-10-31')
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
trade.shape
# Out:
# (9436, 17)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1429955.795596803
# Sharpe:  2.0409648642787803
# =================================
# hit end!

# %%
df_daily_return.head()
# Out:
#         date  daily_return
# 0 2020-07-01      0.000000
# 1 2020-07-02      0.005171
# 2 2020-07-06      0.014679
# 3 2020-07-07     -0.012444
# 4 2020-07-08      0.004840

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                 AAPL      AMGN       AXP        BA       CAT       CRM  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.026969  0.023589  0.033120  0.024771  0.064121  0.045003
# 2020-07-06  0.026969  0.023589  0.033120  0.024771  0.064121  0.045003
# 2020-07-07  0.027054  0.023511  0.033213  0.024161  0.063910  0.050633
# 2020-07-08  0.026969  0.023589  0.033120  0.024771  0.064121  0.045003
#
#                 CSCO       CVX       DIS        GS  ...       MMM       MRK  \
# date                                                ...
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  ...  0.035714  0.035714
# 2020-07-02  0.023589  0.041888  0.023589  0.023589  ...  0.023589  0.062167
# 2020-07-06  0.023589  0.041888  0.023589  0.023589  ...  0.023589  0.062167
# 2020-07-07  0.023511  0.041602  0.023511  0.023511  ...  0.023511  0.061082
# 2020-07-08  0.023589  0.041888  0.023589  0.023589  ...  0.023589  0.062167
#
#                 MSFT       NKE        PG       TRV       UNH        VZ  \
# date
# 2020-07-01  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2020-07-02  0.023589  0.026189  0.056837  0.064121  0.023589  0.023589
# 2020-07-06  0.023589  0.026189  0.056837  0.064121  0.023589  0.023589
# 2020-07-07  0.023511  0.027872  0.058864  0.063910  0.023511  0.023511
# 2020-07-08  0.023589  0.026189  0.056837  0.064121  0.023589  0.023589
#
#                  WBA       WMT
# date
# 2020-07-01  0.035714  0.035714
# 2020-07-02  0.038210  0.040196
# 2020-07-06  0.038210  0.040196
# 2020-07-07  0.037512  0.038150
# 2020-07-08  0.038210  0.040196
#
# [5 rows x 28 columns]

# %%
df_actions.to_csv('df_actions.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
import importlib
import empyrical

from pyfolio import timeseries

importlib.reload(timeseries)
importlib.reload(empyrical)
# Out:
# <module 'empyrical' from 'c:\\Python311\\Lib\\site-packages\\empyrical\\__init__.py'>

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")

# %%
print("==============DRL Strategy Stats===========")
perf_stats_all
# Out:
# ==============DRL Strategy Stats===========
# Annual return          0.306611
# Cumulative returns     0.429956
# Annual volatility      0.135595
# Sharpe ratio           2.040965
# Calmar ratio           4.008197
# Stability              0.920593
# Max drawdown          -0.076496
# Omega ratio            1.404619
# Sortino ratio          3.109407
# Skew                  -0.184632
# Kurtosis               1.023521
# Tail ratio             1.090498
# Daily value at risk   -0.015985
# Alpha                  0.000000
# Beta                   1.000000
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_daily_return.loc[0,'date'],
        end = df_daily_return.loc[len(df_daily_return)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.279047
# Cumulative returns     0.388402
# Annual volatility      0.139129
# Sharpe ratio           1.844560
# Calmar ratio           3.124551
# Stability              0.918675
# Max drawdown          -0.089308
# Omega ratio            1.358960
# Sortino ratio          2.734872
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016510
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return.loc[0,'date'], end='2021-11-01'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (337, 8)
# c:\Python311\Lib\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.661%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>30.661%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>42.996%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.56%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.04</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>4.01</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.65%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.11</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.18</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.599%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.96</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.65</td>
#       <td>2020-09-02</td>
#       <td>2020-10-28</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.37</td>
#       <td>2021-08-16</td>
#       <td>2021-09-21</td>
#       <td>2021-10-20</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.14</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-07-12</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.80</td>
#       <td>2021-01-21</td>
#       <td>2021-01-29</td>
#       <td>2021-02-08</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.55</td>
#       <td>2021-02-24</td>
#       <td>2021-03-04</td>
#       <td>2021-03-10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# c:\Python311\Lib\site-packages\pyfolio\plotting.py:1407: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Daily", "Weekly", "Monthly"])
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Covid</th>
#       <td>0.11%</td>
#       <td>-3.06%</td>
#       <td>3.38%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: PyPortfolioOpt in c:\python311\lib\site-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\python311\lib\site-packages (from PyPortfolioOpt) (1.6.6)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\python311\lib\site-packages (from PyPortfolioOpt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in c:\python311\lib\site-packages (from PyPortfolioOpt) (2.3.1)
# Requirement already satisfied: pandas>=0.19 in c:\python311\lib\site-packages (from PyPortfolioOpt) (2.3.0)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\python311\lib\site-packages (from PyPortfolioOpt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in c:\python311\lib\site-packages (from PyPortfolioOpt) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python311\lib\site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (9.1.2)
# Requirement already satisfied: packaging in c:\python311\lib\site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (25.0)
# Requirement already satisfied: osqp>=0.6.2 in c:\python311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in c:\python311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\python311\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.7.post2)
# Requirement already satisfied: cffi in c:\python311\lib\site-packages (from clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (1.17.1)
# Requirement already satisfied: jinja2 in c:\python311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in c:\python311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (80.9.0)
# Requirement already satisfied: joblib in c:\python311\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python311\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: pycparser in c:\python311\lib\site-packages (from cffi->clarabel>=0.5.0->cvxpy>=1.1.19->PyPortfolioOpt) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python311\lib\site-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#         date      close       high        low       open     volume   tic  \
# 0 2008-12-31   2.565124   2.636954   2.564824   2.583758  607541200  AAPL
# 1 2008-12-31  39.933990  40.258995  39.456858  39.491432    6287200  AMGN
# 2 2008-12-31  14.326869  14.481337  13.832573  13.878913    9625600   AXP
# 3 2008-12-31  32.005898  32.290929  31.128306  31.195813    5443100    BA
# 4 2008-12-31  28.895693  29.173847  28.268230  28.268230    6277400   CAT
#
#        macd    boll_ub    boll_lb     rsi_30      cci_30      dx_30  \
# 0 -0.082003   3.071161   2.436449  42.254777  -80.847278  21.092396
# 1  0.149617  40.761994  38.992589  51.060606   51.895127   8.496588
# 2 -0.919292  18.322188  12.440032  42.554852  -74.811701  24.562341
# 3 -0.279800  32.174385  28.867837  47.440252  157.923151  10.291957
# 4  0.639824  29.617316  24.842692  51.205310   98.904627   9.153607
#
#    close_30_sma  close_60_sma  \
# 0      2.729571      2.840867
# 1     39.188098     38.754529
# 2     15.469929     17.309638
# 3     30.327214     32.389917
# 4     26.046878     25.787324
#
#                                             cov_list  \
# 0  [[0.001348969454281321, 0.00042841305258196536...
# 1  [[0.001348969454281321, 0.00042841305258196536...
# 2  [[0.001348969454281321, 0.00042841305258196536...
# 3  [[0.001348969454281321, 0.00042841305258196536...
# 4  [[0.001348969454281321, 0.00042841305258196536...
#
#                                          return_list
# 0  tic             AAPL      AMGN       AXP      ...
# 1  tic             AAPL      AMGN       AXP      ...
# 2  tic             AAPL      AMGN       AXP      ...
# 3  tic             AAPL      AMGN       AXP      ...
# 4  tic             AAPL      AMGN       AXP      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()
    
    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value 
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)
    
portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#              account_value
# 2020-07-01         1000000
# 2020-07-02  1005253.871381
# 2020-07-06  1014948.792768
# 2020-07-07  1014218.847656
# 2020-07-08  1012644.046581

# %%
a2c_cumpod =(df_daily_return.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_9476\3389022641.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\python311\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python311\lib\site-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in c:\python311\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')

trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
#trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
#trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
#trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)



fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2
        
    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date', 
       'tick0': time_ind[0], 
        'tickmode': 'linear', 
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
